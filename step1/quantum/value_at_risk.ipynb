# %% [markdown]
# # Value at Risk
# ## Introduction
#
# Value at Risk (VaR) is a widely used financial risk metric that estimates the maximum expected loss of a portfolio over a given time horizon at a specified confidence level, based on the probability distribution of returns. Classical VaR calculations for complex portfolios often rely on Monte Carlo simulations, which can be computationally expensive and slow to converge. Quantum computing can improve this process by using Iterative Quantum Amplitude Estimation (IQAE) to estimate loss probabilities more efficiently. IQAE provides a quadratic speedup over classical Monte Carlo methods by estimating expected values with fewer samples, without requiring deep quantum circuits. This makes it particularly suitable for near-term quantum hardware and enables faster, more accurate VaR calculations for high-dimensional and non-linear financial portfolios.
#
# ### Modeling the Value at Risk Problem
#
# As a first step, we have to model the problem mathematically. We will use a simple yet powerful model, which captures the essence of portfolio optimization:

# %% [markdown]
# First, we will import the Python libraries required for this implementation. Classiq, of course, and Numpy.

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy

from classiq import *
from classiq.applications.iqae.iqae import IQAE

# %% [markdown]
# Now, we will define the parameters required for the Value at Risk process, and create the probability distribution function.

# %%
# How many qubits we want the quantum circuit to be
num_qubits = 7

# Mu (μ) represents the Average
mu = 0.7

# Sigma (σ) represents the Standard Deviation
sigma = 0.13

# The Alpha (α) parameter represents the probability in which P(X > v) = 1 - α
ALPHA = 0.07

# Find Alpha in a given precision
TOLERANCE = ALPHA / 10


def get_log_normal_probabilities(mu_normal, sigma_normal, num_points):
    log_normal_mean = np.exp(mu + sigma**2 / 2)
    log_normal_variance = (np.exp(sigma**2) - 1) * np.exp(2 * mu + sigma**2)
    log_normal_stddev = np.sqrt(log_normal_variance)

    # cutting the distribution 3 sigmas from the mean
    low = np.maximum(0, log_normal_mean - 3 * log_normal_stddev)
    high = log_normal_mean + 3 * log_normal_stddev
    print(log_normal_mean, log_normal_variance, log_normal_stddev, low, high)
    x = np.linspace(low, high, num_points)
    return x, scipy.stats.lognorm.pdf(x, s=sigma_normal, scale=np.exp(mu_normal))


# %%
grid_points, probs = get_log_normal_probabilities(mu, sigma, 2**num_qubits)
# Out:
# 2.030841014265948 0.07029323208790372 0.26512870853210846 1.2354548886696226 2.8262271398622736

# %% [markdown]
# ### The Binary Search Approach To Calculate Value At Risk
# We can solve the Value at Risk use-case also with a binary search approach.
# This approach will benefit us from a complexity perspective once we will integrate the quantum function that calculates alpha given an index.

# %%
# This function calculates the alpha classically given the index and the list of probabilities


def calc_alpha(index: int, probs: list[float]):
    sum_probs = sum([probs[i] for i in range(index)])
    return sum_probs

# %%
# This function updates the new index based on the comparison between the measured alpha value and the required value.
# The search size correlates with the current binary search step.


def update_index(index: int, required_alpha: float, alpha_v: float, search_size: int):
    if alpha_v < required_alpha:
        return index + search_size
    return index - search_size

# %%
# This is the main Value at Risk function, which gets the required probability (required_alpha), the index and the alpha calculation function
# We aim to use calc_alpha defined above


def print_status(v, alpha_v, search_size, index):
    print(f"v: {v}, alpha_v: {alpha_v}")
    print(f"{search_size=}")
    print(f"{index=}")
    print("------------------------")


def print_results(grid_points, index, probs):
    print(f"Value at risk at {ALPHA*100}%: {grid_points[index]})")
    global VAR
    print(f"Real VaR", VAR)
    return index


def value_at_risk(required_alpha, index, calc_alpha_func=calc_alpha):
    v = probs[index]
    alpha_v = calc_alpha_func(index, probs)
    search_size = index // 2
    print_status(v, alpha_v, search_size, index)

    # Tolerance represents the accuracy of the alpha we aim to get
    while (not np.isclose(alpha_v, required_alpha, atol=TOLERANCE)) and search_size > 0:
        index = update_index(index, required_alpha, alpha_v, search_size)
        # Binary search, divided by 2 - as we know the function is always growing in that part of the graph.
        search_size = search_size // 2
        v = grid_points[index]
        alpha_v = calc_alpha_func(index, probs)
        print_status(v, alpha_v, search_size, index)

    print_results(grid_points, index, probs)

# %%
def get_initial_index():
    return int(2**num_qubits) // 4


index = get_initial_index()
var_index = value_at_risk(ALPHA, index)
# Out:
# v: 0.5241815104513557, alpha_v: 4.13981577062351
# search_size=16
# index=32
# ------------------------
# v: 1.4358671407883818, alpha_v: 0.32917194167136327
# search_size=8
# index=16
# ------------------------
# v: 1.3356610147290022, alpha_v: 0.04998284288284715
# search_size=4
# index=8
# ------------------------
# v: 1.385764077758692, alpha_v: 0.13827315351482092
# search_size=2
# index=12
# ------------------------
# v: 1.3607125462438472, alpha_v: 0.08509846078461876
# search_size=1
# index=10
# ------------------------
# v: 1.3481867804864247, alpha_v: 0.06566166443778557
# search_size=0
# index=9
# ------------------------
# Value at risk at 7.000000000000001%: 1.3481867804864247)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       2     return int(2**num_qubits) // 4
#       5 index = get_initial_index()
# ----> 6 var_index = value_at_risk(ALPHA, index)
#
# Cell In[5], line 34, in value_at_risk(required_alpha, index, calc_alpha_func)
#      31     alpha_v = calc_alpha_func(index, probs)
#      32     print_status(v, alpha_v, search_size, index)
# ---> 34 print_results(grid_points, index, probs)
#
# Cell In[5], line 15, in print_results(grid_points, index, probs)
#      13 print(f"Value at risk at {ALPHA*100}%: {grid_points[index]})")
#      14 global VAR
# ---> 15 print(f"Real VaR", VAR)
#      16 return index
#
# NameError: name 'VAR' is not defined

# %% [markdown]
# ## Value at Risk using Iterative Quantum Amplitude Estimation (IQAE)
#
# Iterative Quantum Amplitude Estimation (IQAE) is a key algorithm in the quantum computing toolbox. It is useful for quantum-enhanced Monte Carlo methods, which are in use for several important quantum finance applications like Value at Risk (VaR) estimation.
#
# The goal of Quantum Amplitude Estimation (QAE) is to estimate the probability (or amplitude) of a certain outcome from a quantum circuit. Compared to other classical methods, some has been presented above in this notebook - it is potentially quadratically faster.
#
# IQAE is a NISQ-friendly version of the traditional Quantum Amplitude Estimation (QAE), and includes the following stages:
#
# - State preparation encoding the desired probabilty, in this case - for not losing more than $X for an asset or a portfolio of asset.
# - Use controlled applications of the Grover operator (unlike QAE, which utilises Fourier Transform)
# - Measure and update the estimate using classical methods.

# %% [markdown]
# ### Defining The State Preparation for the IQAE Algorithm
#
# In order to use IQAE, we need to define the state preparation function, which includes two main parts:
# - Loading the distribution of the asset values into a quantum state.
# - Defining the payoff function, which marks the states where the asset value is below a certain threshold (the index in this case).
#
# For the first part, we will use Classiq's inpalce_prepare_state function.
# For the second part, we will define a simple comparison operation using Classiq's arithmetic library.

# %%
@qfunc(synthesize_separately=True)
def state_preparation(asset: QArray[QBit], ind: QBit):
    load_distribution(asset=asset)
    payoff(asset=asset, ind=ind)


@qfunc
def load_distribution(asset: QNum):
    inplace_prepare_state(probs, bound=0, target=asset)


@qperm
def payoff(asset: Const[QNum], ind: QBit):
    ind ^= asset < GLOBAL_INDEX

# %%
written_qmod = False


def calc_alpha_quantum(index: int, probs: list[float]):

    # Global variable
    global GLOBAL_INDEX
    GLOBAL_INDEX = index

    # Creation of the model, given the constratins and the circuit preferences
    iqae = IQAE(
        state_prep_op=state_preparation,
        problem_vars_size=num_qubits,
        constraints=Constraints(max_width=28),
        preferences=Preferences(machine_precision=num_qubits),
    )

    qprog = iqae.get_qprog()

    global written_qmod
    qmod = iqae.get_model()
    if not written_qmod:
        written_qmod = True
        show(qprog)

    iqae_res = iqae.run(epsilon=0.05, alpha=0.01)

    # Result of the iterative QAE
    # iqae_res = res[0].value
    measured_payoff = iqae_res.estimation
    confidence_interval = np.array(
        [interval for interval in iqae_res.confidence_interval]
    )
    print("Measured Payoff:", measured_payoff)
    print("Confidence Interval:", confidence_interval)
    return measured_payoff

# %%
index = get_initial_index()

# %%
var = value_at_risk(ALPHA, index, calc_alpha_quantum)
# Out:
# ---------------------------------------------------------------------------
# ClassiqAPIError                           Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 var = value_at_risk(ALPHA, index, calc_alpha_quantum)
#
# Cell In[5], line 21, in value_at_risk(required_alpha, index, calc_alpha_func)
#      19 def value_at_risk(required_alpha, index, calc_alpha_func=calc_alpha):
#      20     v = probs[index]
# ---> 21     alpha_v = calc_alpha_func(index, probs)
#      22     search_size = index // 2
#      23     print_status(v, alpha_v, search_size, index)
#
# Cell In[8], line 18, in calc_alpha_quantum(index, probs)
#      10 # Creation of the model, given the constratins and the circuit preferences
#      11 iqae = IQAE(
#      12     state_prep_op=state_preparation,
#      13     problem_vars_size=num_qubits,
#      14     constraints=Constraints(max_width=28),
#      15     preferences=Preferences(machine_precision=num_qubits),
#      16 )
# ---> 18 qprog = iqae.get_qprog()
#      20 global written_qmod
#      21 qmod = iqae.get_model()
#
# File c:\Users\azain\WhatTheDuck\.venv\Lib\site-packages\classiq\applications\iqae\iqae.py:132, in IQAE.get_qprog(self)
#     130 if self._qprog is None:
#     131     model = self.get_model()
# --> 132     self._qprog = synthesize(model)
#     133 return self._qprog
#
# File c:\Users\azain\WhatTheDuck\.venv\Lib\site-packages\classiq\synthesis.py:101, in synthesize(model, auto_show, constraints, preferences)
#      97     if constraints is not None:
#      98         serialized_model = set_constraints(
#      99             serialized_model, constraints=constraints
#     100         )
# --> 101 result = async_utils.run(synthesize_async(serialized_model))
#     102 if auto_show:
#     103     show(result)
#
# File c:\Users\azain\WhatTheDuck\.venv\Lib\site-packages\classiq\_internals\async_utils.py:34, in run(coro)
#      29 def run(coro: Awaitable[T]) -> T:
#      30     # Use this function instead of asyncio.run, since it ALWAYS
#      31     # creates a new event loop and clears the thread event loop.
#      32     # Never use asyncio.run in library code.
#      33     loop = get_event_loop()
# ---> 34     return loop.run_until_complete(coro)
#
# File c:\Users\azain\WhatTheDuck\.venv\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\futures.py:202, in Future.result(self)
#     200 self.__log_traceback = False
#     201 if self._exception is not None:
# --> 202     raise self._exception.with_traceback(self._exception_tb)
#     203 return self._result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File c:\Users\azain\WhatTheDuck\.venv\Lib\site-packages\classiq\synthesis.py:59, in synthesize_async(serialized_model)
#      55 async def synthesize_async(
#      56     serialized_model: SerializedModel,
#      57 ) -> QuantumProgram:
#      58     model = Model.model_validate_json(serialized_model)
# ---> 59     quantum_program = await ApiWrapper.call_generation_task(model)
#      60     quantum_program.raise_warnings()
#      61     return quantum_program
#
# File c:\Users\azain\WhatTheDuck\.venv\Lib\site-packages\classiq\_internals\api_wrapper.py:131, in ApiWrapper.call_generation_task(cls, model, http_client)
#     125 @classmethod
#     126 async def call_generation_task(
#     127     cls,
#     128     model: Model,
#     129     http_client: httpx.AsyncClient | None = None,
#     130 ) -> generator_result.QuantumProgram:
# --> 131     return await cls._call_job_and_poll(
#     132         routes.TASKS_GENERATE_FULL_PATH,
#     133         model,
#     134         generator_result.QuantumProgram,
#     135         http_client,
#     136     )
#
# File c:\Users\azain\WhatTheDuck\.venv\Lib\site-packages\classiq\_internals\api_wrapper.py:120, in ApiWrapper._call_job_and_poll(cls, url, job_input, result_type, http_client)
#     111 @classmethod
#     112 async def _call_job_and_poll(
#     113     cls,
#    (...)    117     http_client: httpx.AsyncClient | None,
#     118 ) -> ResultType:
#     119     poller = JobPoller(base_url=url)
# --> 120     result = await poller.run_pydantic(
#     121         job_input, timeout_sec=None, http_client=http_client
#     122     )
#     123     return _parse_job_response(result, result_type)
#
# File c:\Users\azain\WhatTheDuck\.venv\Lib\site-packages\classiq\_internals\jobs.py:183, in JobPoller.run_pydantic(self, model, timeout_sec, http_client)
#     173 async def run_pydantic(
#     174     self,
#     175     model: pydantic.BaseModel,
#    (...)    180     # This was added because JSON serializer doesn't serialize complex and UUID,
#     181     # while pydantic does. We should add support for smarter json serialization.
#     182     body = json.loads(model.model_dump_json())
# --> 183     return await self.run(body, timeout_sec, http_client=http_client)
#
# File c:\Users\azain\WhatTheDuck\.venv\Lib\site-packages\classiq\_internals\jobs.py:160, in JobPoller.run(self, body, timeout_sec, http_client)
#     153 async def run(
#     154     self,
#     155     body: dict,
#     156     timeout_sec: float | None,
#     157     http_client: httpx.AsyncClient | None = None,
#     158 ) -> GeneralJobDescription:
#     159     async with client().use_client_or_create(http_client) as async_client:
# --> 160         submit_response = await self._submit(http_client=async_client, body=body)
#     161         job_id = self._parse_job_id_response(response=submit_response)
#     162         poll_url = self._make_poll_url(job_id=job_id)
#
# File c:\Users\azain\WhatTheDuck\.venv\Lib\site-packages\classiq\_internals\jobs.py:96, in JobPoller._submit(self, http_client, body)
#      93 async def _submit(
#      94     self, http_client: httpx.AsyncClient, body: dict
#      95 ) -> httpx.Response:
# ---> 96     return await self._request(
#      97         http_client=http_client, http_method="POST", url=self._base_url, body=body
#      98     )
#
# File c:\Users\azain\WhatTheDuck\.venv\Lib\site-packages\classiq\_internals\jobs.py:85, in JobPoller._request(self, http_client, http_method, url, body)
#      78 async def _request(
#      79     self,
#      80     http_client: httpx.AsyncClient,
#    (...)     83     body: dict | None = None,
#      84 ) -> httpx.Response:
# ---> 85     return await client().request(
#      86         http_client=http_client,
#      87         method=http_method,
#      88         url=url,
#      89         json=body,
#      90         headers=self._additional_headers,
#      91     )
#
# File c:\Users\azain\WhatTheDuck\.venv\Lib\site-packages\classiq\_internals\client.py:114, in try_again_on_failure.<locals>.wrapper(*args, **kwargs)
#     112 for i in range(_RETRY_COUNT):
#     113     try:
# --> 114         return await func(*args, **kwargs)
#     115     except ClassiqExpiredTokenError:
#     116         _logger.info(
#     117             "Token expired when trying to %s with args %s %s",
#     118             func,
#    (...)    121             exc_info=True,
#     122         )
#
# File c:\Users\azain\WhatTheDuck\.venv\Lib\site-packages\classiq\_internals\client.py:232, in Client.request(self, http_client, method, url, json, params, headers)
#     218 response = await http_client.request(
#     219     method=method,
#     220     url=url,
#    (...)    223     headers=headers,
#     224 )
#     225 _logger.debug(
#     226     "HTTP response: %s %s %d (%.0fms)",
#     227     method.upper(),
#    (...)    230     (time.monotonic() - start_time) * 1000,
#     231 )
# --> 232 self.handle_response(response)
#     233 return response
#
# File c:\Users\azain\WhatTheDuck\.venv\Lib\site-packages\classiq\_internals\client.py:183, in Client.handle_response(self, response)
#     181 self._handle_warnings(response)
#     182 if response.is_error:
# --> 183     self._handle_error(response)
#     184 self._handle_success(response)
#
# File c:\Users\azain\WhatTheDuck\.venv\Lib\site-packages\classiq\_internals\client.py:202, in Client._handle_error(response)
#     200 except Exception:  # noqa: S110
#     201     pass
# --> 202 raise ClassiqAPIError(message, response.status_code)
#
# ClassiqAPIError: Call to API failed with code 403: User is not authorized to perform this action. Please contact support@classiq.io for more information
# If you need further assistance, please reach out on our Community Slack channel at: https://short.classiq.io/join-slack or open a support ticket at: https://classiq-community.freshdesk.com/support/tickets/new
